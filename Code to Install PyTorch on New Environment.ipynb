# %%
pip install --user --upgrade ipywidgets notebook jupyterlab
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install torch torchvision torchaudio
# Out:
# ...
#   Using cached filelock-3.17.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached fsspec-2025.2.0-py3-none-any.whl.metadata (11 kB)
# ...
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.3/204.1 MB ? eta -:--:--
#    ---------------------------------------- 0.5/204.1 MB 1.3 MB/s eta 0:02:43
#    ---------------------------------------- 0.5/204.1 MB 1.3 MB/s eta 0:02:43
#    ---------------------------------------- 0.8/204.1 MB 856.8 kB/s eta 0:03:58
#    ---------------------------------------- 1.3/204.1 MB 1.3 MB/s eta 0:02:39
#    ---------------------------------------- 1.6/204.1 MB 1.4 MB/s eta 0:02:29
#    ---------------------------------------- 1.8/204.1 MB 1.3 MB/s eta 0:02:37
#    ---------------------------------------- 2.1/204.1 MB 1.3 MB/s eta 0:02:36
# ...

# %%
pip install jupyter ipywidgets
# Out:
# ...
#   Using cached jupyter-1.1.1-py2.py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached jupyter_console-6.6.3-py3-none-any.whl.metadata (5.8 kB)
# ...
# Using cached jupyter-1.1.1-py2.py3-none-any.whl (2.7 kB)
# Using cached jupyter_console-6.6.3-py3-none-any.whl (24 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install librosa torch numpy matplotlib scikit-learn seaborn scipy noisereduce

# %%
pip install transformers torchaudio datasets
